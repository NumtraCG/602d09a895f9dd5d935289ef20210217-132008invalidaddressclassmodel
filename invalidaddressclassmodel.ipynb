# %% [markdown]
# ***GENERATED CODE FOR invalidaddressclassmodel PIPELINE.***

# %% [markdown]
# ***DON'T EDIT THIS CODE.***

# %% [markdown]
# ***CONNECTOR FUNCTIONS TO READ DATA.***

# %% [markdown]
# ***TRANSFORMATIONS FUNCTIONS THAT WILL BE APPLIED ON DATA***

# %%
from pyspark.sql.functions import dayofmonth, month, year, col
import json
from pyspark.sql.types import IntegerType
from pyspark.ml.feature import StringIndexer
from pyspark.sql.functions import col, when
from pyspark.sql.types import IntegerType
from pyspark.sql.functions import mean, stddev, min, max, col


class CleanseData:
    # def __init__(self,df):
    #     #print()

    def replaceByMean(self, feature, df, mean_=-1):

        meanValue = df.select(mean(col(feature.name)).alias(
            'mean')).collect()[0]["mean"]
        df.fillna(meanValue, subset=[feature.name])
        df.withColumn(feature.name, when(col(feature.name) == " ",
                                         meanValue).otherwise(col(feature.name).cast("Integer")))
        return df

    def replaceByMax(self, feature, df, max_=-1):
        maxValue = df.select(max(col(feature.name)).alias('max')).collect()[
            0]["max"]
        df.fillna(maxValue, subset=[feature.name])
        df = df.withColumn(feature.name,
                           when(col(feature.name) == " ", maxValue).otherwise(col(feature.name)))
        return df

    def replaceByMin(self, feature, df, min_=-1):
        minValue = df.select(min(col(feature.name)).alias('min')).collect()[
            0]["min"]
        df.fillna(minValue, subset=[feature.name])
        df = df.withColumn(feature.name,
                           when(col(feature.name) == " ", minValue).otherwise(col(feature.name)))
        return df

    def replaceByStandardDeviation(self, feature, df, stddev_=-1):
        stddevValue = df.select(stddev(col(feature.name)).alias(
            'stddev')).collect()[0]["stddev"]
        df.fillna(stddevValue, subset=[feature.name])
        df = df.withColumn(feature.name,
                           when(col(feature.name) == " ", stddevValue).otherwise(col(feature.name)))
        return df

    def replaceDateRandomly(self, feature, df):
        fillValue = df.where(col(feature.name).isNotNull()
                             ).head(1)[0][feature.name]
        df.fillna(str(fillValue), subset=[feature.name])
        df = df.withColumn(feature.name,
                           when(col(feature.name) == " ", fillValue).otherwise(col(feature.name)))
        # print("CleanseData:replaceDateRandomly Schema : ", df.#printSchema())
        return df

    def replaceNullValues(self, fList, df):
        featuresList = df.schema.fields
        for featureObj in fList:
            for feat in featuresList:
                if featureObj["feature"] in feat.name:
                    featureName = feat
                    if "mean" in featureObj["replaceby"]:
                        df = self.replaceByMean(featureName, df)
                    elif "max" in featureObj["replaceby"]:
                        df = self.replaceByMax(featureName, df)
                    elif "min" in featureObj["replaceby"]:
                        df = self.replaceByMin(featureName, df)
                    elif "stddev" in featureObj["replaceby"]:
                        df = self.replaceByStandardDeviation(featureName, df)
                    elif "random" in featureObj["replaceby"]:
                        df = self.replaceDateRandomly(featureName, df)
        return df


def StringIndexerTransform(df, params, transformationData={}):
    dfReturn = df
    feature = params["feature"]

    dfReturn = dfReturn.fillna({feature: ''})
    outcol = feature + "_stringindexer"
    indexer = StringIndexer(
        inputCol=feature, outputCol=outcol, handleInvalid="skip")
    indexed = indexer.fit(dfReturn).transform(dfReturn)
    dfReturn = indexed
    distinct_values_list = dfReturn.select(
        outcol).distinct().rdd.map(lambda r: r[0]).collect()
    len_distinct_values_list = len(distinct_values_list)
    if len_distinct_values_list <= 4:
        changed_type_df = dfReturn.withColumn(
            outcol, dfReturn[outcol].cast(IntegerType()))
        return changed_type_df
    return dfReturn


def ExtractDateTransform(df, params, transformationData={}):
    transform_params = params
    dfReturn = df
    feature = transform_params['feature']
    dfReturn = dfReturn.fillna({feature: ''})
    dfReturn = dfReturn.withColumn(
        feature+'dayofmonth', dayofmonth(col(feature)))
    dfReturn = dfReturn.withColumn(feature+'month', month(col(feature)))
    dfReturn = dfReturn.withColumn(feature+'year', year(col(feature)))
    return dfReturn


class TransformationMain:
    # TODO: change df argument in run with following
    def run(transformationDF, config):
        configObj = json.loads(config)
        featureData = configObj["FE"]
        transformationDF = CleanseData().replaceNullValues(featureData, transformationDF)
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'Id', 'transformation_label': 'String Indexer'}], 'feature': 'Id', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
                                                  'count': '339', 'mean': '', 'stddev': '', 'min': '00BCAF55-A996-4F84-BCEA-A8916B45E6BF', 'max': 'FFFF2B39-A937-43EE-8729-A083775038F8', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'Id'}, {'feature_label': 'Id', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('Id')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'CreatedById', 'transformation_label': 'String Indexer'}], 'feature': 'CreatedById', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '339', 'mean': '', 'stddev': '', 'min': '00992C93-D3F0-41DF-820C-CF8CAC7B1A1C', 'max': 'FEFF9944-A52A-4C5E-8BA5-D21445CADCEC', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'CreatedById'}, {'feature_label': 'CreatedById', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('CreatedById')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'UpdatedById', 'transformation_label': 'String Indexer'}], 'feature': 'UpdatedById', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '339', 'mean': '', 'stddev': '', 'min': 'null', 'max': 'null', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'UpdatedById'}, {'feature_label': 'UpdatedById', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('UpdatedById')
        transformationDF = ExtractDateTransform(transformationDF, {'transformationsData': [{'feature_label': 'CreatedOn', 'transformation_label': 'Extract Date'}], 'feature': 'CreatedOn', 'type': 'date', 'selected': 'True', 'replaceby': 'random', 'stats': {
            'count': '', 'mean': '', 'stddev': '', 'min': '', 'max': '', 'missing': '0'}, 'transformation': [{'transformation': 'Extract Date', 'selectedAsDefault': 1}], 'generated': 'False', 'updatedLabel': 'CreatedOn'}, {'feature_label': 'CreatedOn', 'transformation_label': 'Extract Date'})
        transformationDF = transformationDF.drop('CreatedOn')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'UpdatedOn', 'transformation_label': 'String Indexer'}], 'feature': 'UpdatedOn', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '339', 'mean': '', 'stddev': '', 'min': '2020-12-08T11:40:09.000Z', 'max': 'null', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'UpdatedOn'}, {'feature_label': 'UpdatedOn', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('UpdatedOn')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'TenantId', 'transformation_label': 'String Indexer'}], 'feature': 'TenantId', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '339', 'mean': '', 'stddev': '', 'min': '60BF9BD9-23DA-4308-8122-840D6F8692D6', 'max': '60BF9BD9-23DA-4308-8122-840D6F8692D6', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'TenantId'}, {'feature_label': 'TenantId', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('TenantId')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'AddressLine1', 'transformation_label': 'String Indexer'}], 'feature': 'AddressLine1', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '339', 'mean': '4092.5', 'stddev': '4342.06', 'min': '10 Arbor Circle', 'max': 'sads', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'AddressLine1'}, {'feature_label': 'AddressLine1', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('AddressLine1')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'AddressLine2', 'transformation_label': 'String Indexer'}], 'feature': 'AddressLine2', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '339', 'mean': '1010.78', 'stddev': '2525.91', 'min': '# 1623', 'max': '\xa0', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'AddressLine2'}, {'feature_label': 'AddressLine2', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('AddressLine2')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'City', 'transformation_label': 'String Indexer'}], 'feature': 'City', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '339', 'mean': '', 'stddev': '', 'min': 'ARLINGTON', 'max': 'zxc', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'City'}, {'feature_label': 'City', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('City')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'State', 'transformation_label': 'String Indexer'}], 'feature': 'State', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '339', 'mean': '', 'stddev': '', 'min': 'AK', 'max': 'texas', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'State'}, {'feature_label': 'State', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('State')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'Zip', 'transformation_label': 'String Indexer'}], 'feature': 'Zip', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '339', 'mean': '61709.74', 'stddev': '33658.58', 'min': '0', 'max': 'null', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'Zip'}, {'feature_label': 'Zip', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('Zip')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'CountryName', 'transformation_label': 'String Indexer'}], 'feature': 'CountryName', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '339', 'mean': '', 'stddev': '', 'min': 'United States', 'max': 'null', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'CountryName'}, {'feature_label': 'CountryName', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('CountryName')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'CountryCode', 'transformation_label': 'String Indexer'}], 'feature': 'CountryCode', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '339', 'mean': '', 'stddev': '', 'min': 'US', 'max': 'null', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'CountryCode'}, {'feature_label': 'CountryCode', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('CountryCode')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'Latitude', 'transformation_label': 'String Indexer'}], 'feature': 'Latitude', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '339', 'mean': '35.16', 'stddev': '11.79', 'min': '0E-8', 'max': 'null', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'Latitude'}, {'feature_label': 'Latitude', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('Latitude')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'Longitude', 'transformation_label': 'String Indexer'}], 'feature': 'Longitude', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '339', 'mean': '-93.03', 'stddev': '32.92', 'min': '-104.74299020', 'max': 'null', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'Longitude'}, {'feature_label': 'Longitude', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('Longitude')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'Degrees', 'transformation_label': 'String Indexer'}], 'feature': 'Degrees', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '339', 'mean': '', 'stddev': '', 'min': 'null', 'max': 'null', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'Degrees'}, {'feature_label': 'Degrees', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('Degrees')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'Minutes', 'transformation_label': 'String Indexer'}], 'feature': 'Minutes', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '339', 'mean': '', 'stddev': '', 'min': 'null', 'max': 'null', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'Minutes'}, {'feature_label': 'Minutes', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('Minutes')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'Seconds', 'transformation_label': 'String Indexer'}], 'feature': 'Seconds', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '339', 'mean': '', 'stddev': '', 'min': 'null', 'max': 'null', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'Seconds'}, {'feature_label': 'Seconds', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('Seconds')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'VerificationStatus', 'transformation_label': 'String Indexer'}], 'feature': 'VerificationStatus', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '339', 'mean': '', 'stddev': '', 'min': 'Invalid', 'max': 'null', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'VerificationStatus'}, {'feature_label': 'VerificationStatus', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('VerificationStatus')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'Partition', 'transformation_label': 'String Indexer'}], 'feature': 'Partition', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '339', 'mean': '', 'stddev': '', 'min': 'null', 'max': 'null', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'Partition'}, {'feature_label': 'Partition', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('Partition')
        transformationDF = StringIndexerTransform(transformationDF, {'transformationsData': [{'feature_label': 'VerificationCount', 'transformation_label': 'String Indexer'}], 'feature': 'VerificationCount', 'type': 'string', 'selected': 'True', 'replaceby': 'max', 'stats': {
            'count': '339', 'mean': '', 'stddev': '', 'min': 'null', 'max': 'null', 'missing': '0'}, 'transformation': [{'transformation': 'String Indexer', 'selectedAsDefault': 1}], 'updatedLabel': 'VerificationCount'}, {'feature_label': 'VerificationCount', 'transformation_label': 'String Indexer'})
        transformationDF = transformationDF.drop('VerificationCount')
        display(transformationDF.limit(2).toPandas())
        return transformationDF

# %% [markdown]
# ***AUTOML FUNCTIONS***

# %%
from tpot import TPOTClassifier
from sklearn.model_selection import train_test_split
import pyspark


def functionClassification(sparkDF, listOfFeatures, label):
    sparkDF.persist(pyspark.StorageLevel.MEMORY_AND_DISK)
    df = (sparkDF.toPandas())
    X = (df.drop(label, axis=1))[listOfFeatures].values
    y = df[label].values
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, random_state=1, test_size=0.1)
    tpotModel = TPOTClassifier(verbosity=3, n_jobs=-1, generations=10, max_time_mins=5,
                               population_size=15)
    tpotModel.fit(X_train, y_train)
    display(" Accuracy of Model : %s" % tpotModel.score(X_test, y_test))
    data = {'model': tpotModel,
            'X_test': X_test,
            'y_test': y_test,
            'label': label,
            'columnNames': listOfFeatures}
    return data

# %% [markdown]
# ***READING DATAFRAME***

# %%
#%run invalidaddressclassmodelHooks.ipynb
try:
	#sourcePreExecutionHook()

	completeaddress = HDFSConnector.fetch(spark, "{'url': '/FileStore/platform/uploadedSourceFiles/1613567160477_Complete_address1.csv', 'file_type': 'Delimeted', 'delimiter': ',', 'is_header': 'Use Header Line', 'FilePath': '/BigLynx/Complete_address1.csv', 'filename': '1613567160477_Complete_address1.csv', 'viewFileName': 'Complete_address1.csv'}")

except Exception as ex: 
	logging.error(ex)

# %% [markdown]
# ***TRANSFORMING DATAFRAME***

# %%
#%run invalidaddressclassmodelHooks.ipynb
try:
	#transformationPreExecutionHook()

	autofe = TransformationMain.run(completeaddress,json.dumps( {"FE": [{"transformationsData": [{"feature_label": "Id", "transformation_label": "String Indexer"}], "feature": "Id", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "339", "mean": "", "stddev": "", "min": "00BCAF55-A996-4F84-BCEA-A8916B45E6BF", "max": "FFFF2B39-A937-43EE-8729-A083775038F8", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "Id"}, {"transformationsData": [{"transformation_label": "novalue"}], "feature": "IsDeleted", "transformation": [{"transformation": "novalue", "selectedAsDefault": 1}], "type": "numeric", "replaceby": "mean", "selected": "True", "stats": {"count": "339", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "IsDeleted"}, {"transformationsData": [{"feature_label": "CreatedById", "transformation_label": "String Indexer"}], "feature": "CreatedById", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "339", "mean": "", "stddev": "", "min": "00992C93-D3F0-41DF-820C-CF8CAC7B1A1C", "max": "FEFF9944-A52A-4C5E-8BA5-D21445CADCEC", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "CreatedById"}, {"transformationsData": [{"feature_label": "UpdatedById", "transformation_label": "String Indexer"}], "feature": "UpdatedById", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "339", "mean": "", "stddev": "", "min": "null", "max": "null", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "UpdatedById"}, {"transformationsData": [{"feature_label": "CreatedOn", "transformation_label": "Extract Date"}], "feature": "CreatedOn", "type": "date", "selected": "True", "replaceby": "random", "stats": {"count": "", "mean": "", "stddev": "", "min": "", "max": "", "missing": "0"}, "transformation": [{"transformation": "Extract Date", "selectedAsDefault": 1}], "generated": "False", "updatedLabel": "CreatedOn"}, {"transformationsData": [{"feature_label": "UpdatedOn", "transformation_label": "String Indexer"}], "feature": "UpdatedOn", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "339", "mean": "", "stddev": "", "min": "2020-12-08T11:40:09.000Z", "max": "null", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "UpdatedOn"}, {"transformationsData": [{"feature_label": "TenantId", "transformation_label": "String Indexer"}], "feature": "TenantId", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "339", "mean": "", "stddev": "", "min": "60BF9BD9-23DA-4308-8122-840D6F8692D6", "max": "60BF9BD9-23DA-4308-8122-840D6F8692D6", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "TenantId"}, {"transformationsData": [{"feature_label": "AddressLine1", "transformation_label": "String Indexer"}], "feature": "AddressLine1", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "339", "mean": "4092.5", "stddev": "4342.06", "min": "10 Arbor Circle", "max": "sads", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "AddressLine1"}, {"transformationsData": [{"feature_label": "AddressLine2", "transformation_label": "String Indexer"}], "feature": "AddressLine2", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "339", "mean": "1010.78", "stddev": "2525.91", "min": "# 1623", "max": "\u00a0", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "AddressLine2"}, {"transformationsData": [{"feature_label": "City", "transformation_label": "String Indexer"}], "feature": "City", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "339", "mean": "", "stddev": "", "min": "ARLINGTON", "max": "zxc", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "City"}, {"transformationsData": [{"feature_label": "State", "transformation_label": "String Indexer"}], "feature": "State", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "339", "mean": "", "stddev": "", "min": "AK", "max": "texas", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "State"}, {"transformationsData": [{"feature_label": "Zip", "transformation_label": "String Indexer"}], "feature": "Zip", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "339", "mean": "61709.74", "stddev": "33658.58", "min": "0", "max": "null", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "Zip"}, {"transformationsData": [{"feature_label": "CountryName", "transformation_label": "String Indexer"}], "feature": "CountryName", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "339", "mean": "", "stddev": "", "min": "United States", "max": "null", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "CountryName"}, {"transformationsData": [{"feature_label": "CountryCode", "transformation_label": "String Indexer"}], "feature": "CountryCode", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "339", "mean": "", "stddev": "", "min": "US", "max": "null", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "CountryCode"}, {"transformationsData": [{"feature_label": "Latitude", "transformation_label": "String Indexer"}], "feature": "Latitude", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "339", "mean": "35.16", "stddev": "11.79", "min": "0E-8", "max": "null", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "Latitude"}, {"transformationsData": [{"feature_label": "Longitude", "transformation_label": "String Indexer"}], "feature": "Longitude", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "339", "mean": "-93.03", "stddev": "32.92", "min": "-104.74299020", "max": "null", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "Longitude"}, {"transformationsData": [{"feature_label": "Degrees", "transformation_label": "String Indexer"}], "feature": "Degrees", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "339", "mean": "", "stddev": "", "min": "null", "max": "null", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "Degrees"}, {"transformationsData": [{"feature_label": "Minutes", "transformation_label": "String Indexer"}], "feature": "Minutes", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "339", "mean": "", "stddev": "", "min": "null", "max": "null", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "Minutes"}, {"transformationsData": [{"feature_label": "Seconds", "transformation_label": "String Indexer"}], "feature": "Seconds", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "339", "mean": "", "stddev": "", "min": "null", "max": "null", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "Seconds"}, {"transformationsData": [{"feature_label": "VerificationStatus", "transformation_label": "String Indexer"}], "feature": "VerificationStatus", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "339", "mean": "", "stddev": "", "min": "Invalid", "max": "null", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "VerificationStatus"}, {"transformationsData": [{"feature_label": "Partition", "transformation_label": "String Indexer"}], "feature": "Partition", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "339", "mean": "", "stddev": "", "min": "null", "max": "null", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "Partition"}, {"transformationsData": [{"feature_label": "VerificationCount", "transformation_label": "String Indexer"}], "feature": "VerificationCount", "type": "string", "selected": "True", "replaceby": "max", "stats": {"count": "339", "mean": "", "stddev": "", "min": "null", "max": "null", "missing": "0"}, "transformation": [{"transformation": "String Indexer", "selectedAsDefault": 1}], "updatedLabel": "VerificationCount"}, {"feature": "Id_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "real", "selected": "True", "stats": {"count": "339", "mean": "169.0", "stddev": "98.01", "min": "0.0", "max": "338.0", "missing": "0"}, "updatedLabel": "Id_stringindexer_transfor..."}, {"feature": "CreatedById_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "real", "selected": "True", "stats": {"count": "339", "mean": "121.02", "stddev": "89.74", "min": "0.0", "max": "284.0", "missing": "0"}, "updatedLabel": "CreatedById_stringindexer..."}, {"feature": "UpdatedById_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "numeric", "selected": "True", "stats": {"count": "339", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "UpdatedById_stringindexer..."}, {"feature": "CreatedOn_dayofmonth", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "numeric", "generated": "True", "selected": "True", "stats": {"count": "339", "mean": "16.04", "stddev": "8.75", "min": "1", "max": "31", "missing": "0"}, "updatedLabel": "CreatedOn_dayofmonth"}, {"feature": "CreatedOn_month", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "numeric", "generated": "True", "selected": "True", "stats": {"count": "339", "mean": "8.82", "stddev": "3.02", "min": "1", "max": "12", "missing": "0"}, "updatedLabel": "CreatedOn_month"}, {"feature": "CreatedOn_year", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "numeric", "generated": "True", "selected": "True", "stats": {"count": "339", "mean": "2020.05", "stddev": "0.37", "min": "2017", "max": "2021", "missing": "0"}, "updatedLabel": "CreatedOn_year"}, {"feature": "UpdatedOn_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "numeric", "selected": "True", "stats": {"count": "339", "mean": "0.01", "stddev": "0.12", "min": "0", "max": "2", "missing": "0"}, "updatedLabel": "UpdatedOn_stringindexer_t..."}, {"feature": "TenantId_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "numeric", "selected": "True", "stats": {"count": "339", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "TenantId_stringindexer_tr..."}, {"feature": "AddressLine1_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "real", "selected": "True", "stats": {"count": "339", "mean": "141.98", "stddev": "95.02", "min": "0.0", "max": "309.0", "missing": "0"}, "updatedLabel": "AddressLine1_stringindexe..."}, {"feature": "AddressLine2_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "real", "selected": "True", "stats": {"count": "339", "mean": "106.87", "stddev": "85.21", "min": "0.0", "max": "266.0", "missing": "0"}, "updatedLabel": "AddressLine2_stringindexe..."}, {"feature": "City_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "real", "selected": "True", "stats": {"count": "339", "mean": "73.19", "stddev": "67.11", "min": "0.0", "max": "214.0", "missing": "0"}, "updatedLabel": "City_stringindexer_transf..."}, {"feature": "State_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "real", "selected": "True", "stats": {"count": "339", "mean": "8.01", "stddev": "10.1", "min": "0.0", "max": "46.0", "missing": "0"}, "updatedLabel": "State_stringindexer_trans..."}, {"feature": "Zip_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "real", "selected": "True", "stats": {"count": "339", "mean": "115.52", "stddev": "86.8", "min": "0.0", "max": "276.0", "missing": "0"}, "updatedLabel": "Zip_stringindexer_transfo..."}, {"feature": "CountryName_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "numeric", "selected": "True", "stats": {"count": "339", "mean": "0.04", "stddev": "0.19", "min": "0", "max": "1", "missing": "0"}, "updatedLabel": "CountryName_stringindexer..."}, {"feature": "CountryCode_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "numeric", "selected": "True", "stats": {"count": "339", "mean": "0.04", "stddev": "0.19", "min": "0", "max": "1", "missing": "0"}, "updatedLabel": "CountryCode_stringindexer..."}, {"feature": "Latitude_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "real", "selected": "True", "stats": {"count": "339", "mean": "56.04", "stddev": "64.1", "min": "0.0", "max": "194.0", "missing": "0"}, "updatedLabel": "Latitude_stringindexer_tr..."}, {"feature": "Longitude_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "real", "selected": "True", "stats": {"count": "339", "mean": "56.04", "stddev": "64.1", "min": "0.0", "max": "194.0", "missing": "0"}, "updatedLabel": "Longitude_stringindexer_t..."}, {"feature": "Degrees_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "numeric", "selected": "True", "stats": {"count": "339", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "Degrees_stringindexer_tra..."}, {"feature": "Minutes_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "numeric", "selected": "True", "stats": {"count": "339", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "Minutes_stringindexer_tra..."}, {"feature": "Seconds_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "numeric", "selected": "True", "stats": {"count": "339", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "Seconds_stringindexer_tra..."}, {"feature": "VerificationStatus_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "numeric", "selected": "True", "stats": {"count": "339", "mean": "0.12", "stddev": "0.41", "min": "0", "max": "2", "missing": "0"}, "updatedLabel": "VerificationStatus_string..."}, {"feature": "Partition_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "numeric", "selected": "True", "stats": {"count": "339", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "Partition_stringindexer_t..."}, {"feature": "VerificationCount_stringindexer_transform", "transformation": [{"transformation": "novalue", "selectedAsDefault": 0}], "transformationsData": [{"transformation_label": "novalue"}], "type": "numeric", "selected": "True", "stats": {"count": "339", "mean": "0.0", "stddev": "0.0", "min": "0", "max": "0", "missing": "0"}, "updatedLabel": "VerificationCount_stringi..."}]}))

	#transformationPostExecutionHook(autofe)

except Exception as ex: 
	logging.error(ex)

# %% [markdown]
# ***TRAIN MODEL***

# %%
#%run invalidaddressclassmodelHooks.ipynb
try:
	#mlPreExecutionHook()

	dataAutoML=functionClassification(autofe, ["Id_stringindexer", "IsDeleted", "CreatedById_stringindexer", "UpdatedById_stringindexer", "UpdatedOn_stringindexer", "TenantId_stringindexer", "AddressLine1_stringindexer", "AddressLine2_stringindexer", "City_stringindexer", "State_stringindexer", "Zip_stringindexer", "CountryName_stringindexer", "CountryCode_stringindexer", "Latitude_stringindexer", "Longitude_stringindexer", "Degrees_stringindexer", "Minutes_stringindexer", "Seconds_stringindexer", "Partition_stringindexer", "VerificationCount_stringindexer", "CreatedOn_dayofmonth", "CreatedOn_month", "CreatedOn_year"], "VerificationStatus_stringindexer")

	#mlPostExecutionHook(dataAutoML)

except Exception as ex: 
	logging.error(ex)

# %% [markdown]
# ***PREDICT ON TRAINED MODEL***

# %%
import pandas as pd
import numpy as np
import sklearn.metrics

try:
    model=dataAutoML['model']
    X_test=dataAutoML['X_test']
    y_test=dataAutoML['y_test']
    label=dataAutoML['label']
    columnNames=dataAutoML['columnNames']
    if label in columnNames:
        columnNames.remove(label)
    predicted=label+"_predicted"
    y_predicted=model.predict(X_test)
    df =pd.DataFrame(X_test , columns=columnNames)
    df[label]=y_test
    df[predicted]=y_predicted
    columnNames.insert(0,predicted)
    columnNames.insert(0,label)
    Accuracy = np.round((100 * sklearn.metrics.accuracy_score(y_true=y_test, y_pred=y_predicted)), 1)
    F1= np.round(
            (100 * sklearn.metrics.f1_score(y_true=y_test, y_pred=y_predicted, average="weighted")), 1)
    Precision= np.round((
                100 * sklearn.metrics.precision_score(y_true=y_test, y_pred=y_predicted, average="weighted")), 1)
    Recall = np.round((
                100 * sklearn.metrics.recall_score(y_true=y_test, y_pred=y_predicted, average="weighted")), 1)
    display(" Accuracy of Prediction on test data    : %s"%Accuracy)
    display(" F1 score of Prediction on test data    : %s"%F1)
    display(" Precision of Prediction on test data   : %s"%Precision)
    display(" Recall of Prediction on test data      : %s"%Recall)
    display(df.head())
except Exception as ex:
    logging.error(ex)
